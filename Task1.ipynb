# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/ecommerce_customer_data_custom_ratios.csv")
print(df.head())
print(df.info())
print(df.isnull().sum())
df.drop_duplicates(inplace=True)
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())
print(df.describe())
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
df['Month'] = df['Purchase Date'].dt.to_period('M').astype(str)
monthly_sales = df.groupby('Month')['Total Purchase Amount'].sum()
plt.figure(figsize=(10,6))
monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Purchase Trend")
plt.xlabel("Month")
plt.ylabel("Total Purchase Amount")
plt.xticks(rotation=45)
plt.show()
plt.figure(figsize=(10,6))
sns.countplot(x='Churn', data=df)
plt.title("Customer Churn")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()
plt.figure(figsize=(10,6))
df['Product Category'].value_counts().plot(kind='bar')
plt.title("Top Product Categories")
plt.xlabel("Product Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
plt.figure(figsize=(10,6))
df['Gender'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)
plt.title("Gender Distribution")
plt.ylabel('')
plt.show()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %% [markdown]
# <div style="page-break-before: always;"></div>
# Customer Behavior Analysis
#
# Objective
# Analyze customer transactions and behavior to identify purchase patterns and churn risks.
#
# Data Cleaning and Feature Engineering
# Removed duplicate records
# Handled missing values using median replacement
# Converted purchase date into datetime format
# Created monthly sales feature
#
# Customer Segmentation
# Customers were analyzed based on:
# purchase behavior
# churn trends
# product category preferences
#
# Purchase Patterns and Retention Trends
# Electronics and Home categories had high purchases
# Monthly sales varied across different periods
# Churn analysis showed retention improvement opportunities
#
# Recommendations for Alfido Tech
# Focus marketing on popular categories
# Offer loyalty rewards to repeat customers
# Use personalized offers to reduce churn
# Run seasonal promotions during high-sales months
# Improve customer engagement using targeted campaigns
#
# Conclusion
# The analysis identified important customer behavior trends and business opportunities that can help improve engagement and retention.
